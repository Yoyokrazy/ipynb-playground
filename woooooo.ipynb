# %% [markdown]
# ## This is a header

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# - Image Cell
#
# ![vsc](attachment:image.png)

# %%
a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
# restart kernel command id: jupyter.restartkernel

# not sure what's hanging here... 
# %pip install pandas
import pandas as pd

data = pd.DataFrame({"x1":["y", "x", "y", "x", "x", "y"],  # Construct a pandas DataFrame
                     "x2":range(16, 22),
                     "x3":range(1, 7),
                     "x4":["a", "b", "c", "d", "e", "f"],
                     "x5":range(30, 24, - 1)})
print(data)
# Out:
# ...
#
# ...
#   x1  x2  x3 x4  x5
# 0  y  16   1  a  30
# 1  x  17   2  b  29
# 2  y  18   3  c  28
# 3  x  19   4  d  27
# 4  x  20   5  e  26
# 5  y  21   6  f  25

# %%
for i in range(1000):
	print(i*i)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744
# 7921
# 8100
# 8281
# 8464
# 8649
# 8836
# 9025
# 9216
# 9409
# 9604
# 9801
# 10000
# 10201
# 10404
# 10609
# 10816
# 11025
# 11236
# 11449
# 11664
# 11881
# 12100
# 12321
# 12544
# 12769
# 12996
# 13225
# 13456
# 13689
# 13924
# 14161
# 14400
# 14641
# 14884
# 15129
# 15376
# 15625
# 15876
# 16129
# 16384
# 16641
# 16900
# 17161
# 17424
# 17689
# 17956
# 18225
# 18496
# 18769
# 19044
# 19321
# 19600
# 19881
# 20164
# ...

# %%
data_med = data["x2"].median()                             # Calculate median
print(data_med)                                            # Print median
# Out:
# 18.5
