# %%
print("ooooooh a new notebook")
# Out:
# ooooooh a new notebook

# %%
print("LETS DO SOME CODE")

# %% [markdown]
# ![Alt text](image.png)
# ![image.png](attachment:image.png)
#
# <!-- ![Alt text](images/bebop.png)
# ![layla.png](attachment:layla.png) -->
#
#
#
# ![Alt text](images/code.png)
